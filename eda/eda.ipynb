# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
data = pd.read_csv('../merged_file.csv')
data.head()
# Out:
#                DATE  B.FAST  LUNCH  Snacks   DINNER
# 0  01-05-2023 00:00   111.0  195.0   108.0    137.0
# 1  02-05-2023 00:00    95.0  175.0   115.0    138.0
# 2  03-05-2023 00:00    95.0  203.0   129.0    134.0
# 3  04-05-2023 00:00    93.0  184.0   131.0    179.0
# 4  05-05-2023 00:00   112.0  121.0    95.0    117.0

# %%
# concatenating another dataset
data2 = pd.read_excel('../../../../SALE PLAKSHA UNIVERSITY 08.2023-.xlsx')
# deleting the first four rows
data2 = data2.iloc[4:]
# renaming the columns
data2.columns = ['DATE', 'B.FAST', 'LUNCH', 'Snacks', 'DINNER']
data2.head()
# Out:
#                   DATE B.FAST LUNCH Snacks DINNER
# 4  2023-08-01 00:00:00     36    39     34     49
# 5  2023-08-02 00:00:00     43    42     38     41
# 6  2023-08-03 00:00:00     34    43     32     34
# 7  2023-08-04 00:00:00     34    51     39     45
# 8  2023-08-05 00:00:00     54    81     23     39

# %%
len(data)
# Out:
# 99

# %%
# changing the column names to lower case
data.columns = data.columns.str.lower()
data2.columns = data2.columns.str.lower()

# %%
def format_columns(data):
    data.columns = data.columns.str.lower()
    data.rename(columns={'b.fast':'breakfast'}, inplace=True)
    data.rename(columns={' dinner':'dinner'}, inplace=True)
    return data

# %%
data = format_columns(data)
data.head()
# Out:
#                date  breakfast  lunch  snacks  dinner
# 0  01-05-2023 00:00      111.0  195.0   108.0   137.0
# 1  02-05-2023 00:00       95.0  175.0   115.0   138.0
# 2  03-05-2023 00:00       95.0  203.0   129.0   134.0
# 3  04-05-2023 00:00       93.0  184.0   131.0   179.0
# 4  05-05-2023 00:00      112.0  121.0    95.0   117.0

# %%
data2 = format_columns(data2)
data2.head()
# Out:
#                   date breakfast lunch snacks dinner
# 4  2023-08-01 00:00:00        36    39     34     49
# 5  2023-08-02 00:00:00        43    42     38     41
# 6  2023-08-03 00:00:00        34    43     32     34
# 7  2023-08-04 00:00:00        34    51     39     45
# 8  2023-08-05 00:00:00        54    81     23     39

# %%
# getting all rows with null values
null_rows = data[data.isnull().any(axis=1)]
null_rows
# Out:
#    date  breakfast  lunch  snacks  dinner
# 92  NaN        NaN    NaN     NaN     NaN
# 93  NaN        NaN    NaN     NaN     NaN
# 94  NaN        NaN    NaN     NaN     NaN
# 95  NaN        NaN    NaN     NaN     NaN
# 96  NaN        NaN    NaN     NaN     NaN
# 97  NaN        NaN    NaN     NaN     NaN
# 98             NaN    NaN     NaN     NaN

# %%
null_rows2 = data2[data2.isnull().any(axis=1)]
null_rows2
# Out:
#       date breakfast lunch snacks dinner
# 35     NaN      5842  8918   4945   7056
# 36  THALI-       NaN   NaN    NaN    NaN
# 41     NaN       NaN   NaN    NaN    NaN
# 42     NaN       NaN   NaN    NaN    NaN
# 43     NaN       NaN   NaN    NaN    NaN
# 44     NaN       NaN   NaN    NaN    NaN
# 45     NaN       NaN   NaN    NaN    NaN
# 46     NaN       NaN   NaN    NaN    NaN
# 47     NaN       NaN   NaN    NaN    NaN
# 48               NaN   NaN    NaN    NaN

# %%
data2 = data2.dropna()
# dropping the last 4 rows
data2 = data2[:-4]
data2.tail()
# Out:
#                    date breakfast lunch snacks dinner
# 30  2023-08-27 00:00:00       155   371    175    310
# 31  2023-08-28 00:00:00       271   450    265    341
# 32  2023-08-29 00:00:00       237   402    312    356
# 33  2023-08-30 00:00:00       224   377    278    374
# 34  2023-08-31 00:00:00       198   327    251    272

# %%
# removing null rows
data = data.dropna()
data.tail()
# Out:
#                 date  breakfast  lunch  snacks  dinner
# 87  27-07-2023 00:00       37.0   51.0    33.0    54.0
# 88  28-07-2023 00:00       48.0   68.0    44.0    59.0
# 89  29-07-2023 00:00       45.0   39.0    34.0    48.0
# 90  30-07-2023 00:00       49.0   37.0    40.0    43.0
# 91  31-07-2023 00:00       44.0   51.0    37.0    36.0

# %%
data.columns
# Out:
# Index(['date', 'breakfast', 'lunch', 'snacks', 'dinner'], dtype='object')

# %%
data2.columns
# Out:
# Index(['date', 'breakfast', 'lunch', 'snacks', 'dinner'], dtype='object')

# %%
# turning the breakfast, lunch, snacks and dinner column into integers
data['breakfast'] = data['breakfast'].astype(int)
data['lunch'] = data['lunch'].astype(int)
data['snacks'] = data['snacks'].astype(int)
data['dinner'] = data['dinner'].astype(int)
data.head()
# Out:
#                date  breakfast  lunch  snacks  dinner
# 0  01-05-2023 00:00        111    195     108     137
# 1  02-05-2023 00:00         95    175     115     138
# 2  03-05-2023 00:00         95    203     129     134
# 3  04-05-2023 00:00         93    184     131     179
# 4  05-05-2023 00:00        112    121      95     117

# %%
data2['breakfast'] = data2['breakfast'].astype(int)
data2['lunch'] = data2['lunch'].astype(int)
data2['snacks'] = data2['snacks'].astype(int)
data2['dinner'] = data2['dinner'].astype(int)
data2.head()
# Out:
#                   date  breakfast  lunch  snacks  dinner
# 4  2023-08-01 00:00:00         36     39      34      49
# 5  2023-08-02 00:00:00         43     42      38      41
# 6  2023-08-03 00:00:00         34     43      32      34
# 7  2023-08-04 00:00:00         34     51      39      45
# 8  2023-08-05 00:00:00         54     81      23      39

# %%
# creating a column for day of the week
data['day'] = pd.to_datetime(data['date'], dayfirst=True).dt.day_name()
data['month'] = pd.to_datetime(data['date'], dayfirst=True).dt.month_name()
data.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May

# %%
print(len(data))
print(len(data2))
# Out:
# 92
# 31

# %%
data2['day'] = pd.to_datetime(data2['date'], dayfirst=True).dt.day_name()
data2['month'] = pd.to_datetime(data2['date'], dayfirst=True).dt.month_name()
data2.head()
# Out:
#                   date  breakfast  lunch  snacks  dinner        day   month
# 4  2023-08-01 00:00:00         36     39      34      49    Tuesday  August
# 5  2023-08-02 00:00:00         43     42      38      41  Wednesday  August
# 6  2023-08-03 00:00:00         34     43      32      34   Thursday  August
# 7  2023-08-04 00:00:00         34     51      39      45     Friday  August
# 8  2023-08-05 00:00:00         54     81      23      39   Saturday  August

# %%
# concatenating the two datasets
data = pd.concat([data, data2], ignore_index=True)
data[91:100]
# Out:
#                    date  breakfast  lunch  snacks  dinner        day   month
# 91     31-07-2023 00:00         44     51      37      36     Monday    July
# 92  2023-08-01 00:00:00         36     39      34      49    Tuesday  August
# 93  2023-08-02 00:00:00         43     42      38      41  Wednesday  August
# 94  2023-08-03 00:00:00         34     43      32      34   Thursday  August
# 95  2023-08-04 00:00:00         34     51      39      45     Friday  August
# 96  2023-08-05 00:00:00         54     81      23      39   Saturday  August
# 97  2023-08-06 00:00:00         50     30      24      43     Sunday  August
# 98  2023-08-07 00:00:00         41     51      28      52     Monday  August
# 99  2023-08-08 00:00:00         53     35      11      45    Tuesday  August

# %%
len(data)
# Out:
# 123

# %%
data.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May

# %%
data.tail()
# Out:
#                     date  breakfast  lunch  snacks  dinner        day   month
# 118  2023-08-27 00:00:00        155    371     175     310     Sunday  August
# 119  2023-08-28 00:00:00        271    450     265     341     Monday  August
# 120  2023-08-29 00:00:00        237    402     312     356    Tuesday  August
# 121  2023-08-30 00:00:00        224    377     278     374  Wednesday  August
# 122  2023-08-31 00:00:00        198    327     251     272   Thursday  August

# %%
# saving the dataset 
data.to_csv('../may_till_aug_file.csv', index=False)

# %%
cleaned = pd.read_csv('../may_till_aug_file.csv')
cleaned.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May

# %% [markdown]
# Key Assumptions:
# - Faculty members do not come for breakfast.
# - Faculty members do not come for dinner.
# - Faculty members do not come for meals on weekends.

# %% [markdown]
# For the month of May:
# - 102 students in UG26
# - 86 students in UG25
# - 35 from Faculty
# - 27 from Staff
# - 11 from TLP
# Hence, total of 261 people that on average comes for meals.

# %%
faculty_number = 35
ug26 = 102
ug25 = 86
staff = 27
mess_workers = 15

def max_footfall(total_number, day):
    if day in ['Saturday', 'Sunday']:
        footfall = total_number - faculty_number - staff
    else:
        footfall = total_number
    return footfall

# %%
may_breakfast_max = 225
may_lunch_max = 277
may_snacks_max = 225
may_dinner_max = 225

# %%
may = data[data['month'] == 'May']
june = data[data['month'] == 'June']
july = data[data['month'] == 'July']
august = data[data['month'] == 'August']

# %%
may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# creating a new column for footfall for each meal 
may['breakfast_footfall'] = may.apply(lambda x: max_footfall(may_breakfast_max, x['day']), axis=1)
may['lunch_footfall'] = may.apply(lambda x: max_footfall(may_lunch_max, x['day']), axis=1)
may['snacks_footfall'] = may.apply(lambda x: max_footfall(may_snacks_max, x['day']), axis=1)
may['dinner_footfall'] = may.apply(lambda x: max_footfall(may_dinner_max, x['day']), axis=1)

# %%
# creating a column for proportion of people who ate each meal
may['breakfast_proportion'] = may['breakfast']/may['breakfast_footfall']
may['lunch_proportion'] = may['lunch']/may['lunch_footfall']
may['snacks_proportion'] = may['snacks']/may['snacks_footfall']
may['dinner_proportion'] = may['dinner']/may['dinner_footfall']

# %%
may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  dinner_footfall  \
# 0                 225             277              225              225
# 1                 225             277              225              225
# 2                 225             277              225              225
# 3                 225             277              225              225
# 4                 225             277              225              225
#
#    breakfast_proportion  lunch_proportion  snacks_proportion  \
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
features = [
    'bogo',
    'celebration',
    'chicken',
    'weekend',
    'exam',
    'guest',
    'holiday',
    'fasting',
    'north',
]

# creating columns for each feature
for feature in features:
    may[feature] = 0

may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 0                 225             277              225  ...
# 1                 225             277              225  ...
# 2                 225             277              225  ...
# 3                 225             277              225  ...
# 4                 225             277              225  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 0           0.608889     0            0        0        0     0      0
# ...

# %%
bogo_days = ['Wednesday', 'Friday']
# updating the bogo column
may.loc[may['day'].isin(bogo_days), 'bogo'] = 1
may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 0                 225             277              225  ...
# 1                 225             277              225  ...
# 2                 225             277              225  ...
# 3                 225             277              225  ...
# 4                 225             277              225  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 0           0.608889     0            0        0        0     0      0
# ...

# %%
chicken_days = ['Monday', 'Wednesday', 'Friday']
# updating the chicken column
may.loc[may['day'].isin(chicken_days), 'chicken'] = 1
may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 0                 225             277              225  ...
# 1                 225             277              225  ...
# 2                 225             277              225  ...
# 3                 225             277              225  ...
# 4                 225             277              225  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 0           0.608889     0            0        1        0     0      0
# ...

# %%
weekend_days = ['Saturday', 'Sunday']
# updating the weekend column
may.loc[may['day'].isin(weekend_days), 'weekend'] = 1
may.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 0                 225             277              225  ...
# 1                 225             277              225  ...
# 2                 225             277              225  ...
# 3                 225             277              225  ...
# 4                 225             277              225  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 0           0.608889     0            0        1        0     0      0
# ...

# %%
# getting the first 15 columns and their entries
may.iloc[:, :15].head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  dinner_footfall  \
# 0                 225             277              225              225
# 1                 225             277              225              225
# 2                 225             277              225              225
# 3                 225             277              225              225
# 4                 225             277              225              225
#
#    breakfast_proportion  lunch_proportion  snacks_proportion  \
# ...

# %%
# updating to proportions to 0.85 if the proportions are greater than 1
may.loc[may['breakfast_proportion'] > 1, 'breakfast_proportion'] = 0.85
may.loc[may['lunch_proportion'] > 1, 'lunch_proportion'] = 0.85
may.loc[may['snacks_proportion'] > 1, 'snacks_proportion'] = 0.85
may.loc[may['dinner_proportion'] > 1, 'dinner_proportion'] = 0.85

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# doing some visualizations
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x="day", y="breakfast_proportion", data=may)
ax.set_title('Breakfast Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="lunch_proportion", data=may)
ax.set_title('Lunch Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="snacks_proportion", datsa=may)
ax.set_title('Snacks Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="dinner_proportion", data=may)
ax.set_title('Dinner Proportion')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alli Ajagbe\OneDrive - Plaksha University\Desktop\Personals\projects\mlpr\eda\eda.ipynb Cell 45 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Alli%20Ajagbe/OneDrive%20-%20Plaksha%20University/Desktop/Personals/projects/mlpr/eda/eda.ipynb#X61sZmlsZQ%3D%3D?line=11'>12</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/Alli%20Ajagbe/OneDrive%20-%20Plaksha%20University/Desktop/Personals/projects/mlpr/eda/eda.ipynb#X61sZmlsZQ%3D%3D?line=13'>14</a> plt.figure(figsize=(10, 6))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Alli%20Ajagbe/OneDrive%20-%20Plaksha%20University/Desktop/Personals/projects/mlpr/eda/eda.ipynb#X61sZmlsZQ%3D%3D?line=14'>15</a> ax = sns.barplot(x="day", y="snacks_proportion", datsa=may)
# ...

# %%
plt.figure(figsize=(10, 6))
# Plot bars individually based on the "bogo" value

may_bogo = may[['day', 'dinner_proportion', 'bogo']]

for index, row in may_bogo.iterrows():
    color = 'red' if row['bogo'] == 1 else 'blue'
    plt.bar(row['day'], row['dinner_proportion'], color=color, edgecolor='none')

plt.title('Dinner Proportion')
plt.xlabel('Day')
plt.ylabel('Proportion')
plt.grid(False)
plt.show()

# %%
# quantifying the effect of bogo on dinner
# getting the average dinner proportion for bogo days
bogo_dinner = may[may['bogo'] == 1]['dinner_proportion'].mean()
# getting the average dinner proportion for non-bogo days
non_bogo_dinner = may[may['bogo'] == 0]['dinner_proportion'].mean()
# calculating the difference
bogo_effect = bogo_dinner - non_bogo_dinner
bogo_effect
# Out:
# -0.14891061260181915

# %%
# creating a canvas for 3 plots

# plotting the effect of weekend on the meal proportion
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

may_meals = may[['day', 'breakfast_proportion', 'lunch_proportion', 'snacks_proportion', 'dinner_proportion', 'weekend']]

for index, row in may_meals.iterrows():
    color = 'red' if row['weekend'] == 1 else 'blue'
    axes[0].bar(row['day'][:-3], row['breakfast_proportion'], color=color, edgecolor='none')
    axes[1].bar(row['day'][:-3], row['lunch_proportion'], color=color, edgecolor='none')
    axes[2].bar(row['day'][:-3], row['snacks_proportion'], color=color, edgecolor='none')
    axes[3].bar(row['day'][:-3], row['dinner_proportion'], color=color, edgecolor='none')

axes[0].set_title('Breakfast Proportion')
axes[1].set_title('Lunch Proportion')
axes[2].set_title('Snacks Proportion')
axes[3].set_title('Dinner Proportion')

axes[0].set_xlabel('Day')
axes[1].set_xlabel('Day')
axes[2].set_xlabel('Day')
axes[3].set_xlabel('Day')

axes[0].set_ylabel('Proportion')
axes[1].set_ylabel('Proportion')
axes[2].set_ylabel('Proportion')
axes[3].set_ylabel('Proportion')

axes[0].grid(False)
axes[1].grid(False)
axes[2].grid(False)
axes[3].grid(False)

plt.show()

# %%
# quantifying the effect of weekend on each meal
# getting the average breakfast proportion for weekend days
weekend_breakfast = may[may['weekend'] == 1]['breakfast_proportion'].mean()
# getting the average breakfast proportion for non-weekend days
non_weekend_breakfast = may[may['weekend'] == 0]['breakfast_proportion'].mean()
# calculating the difference
weekend_breakfast_effect = weekend_breakfast - non_weekend_breakfast

# getting the average lunch proportion for weekend days
weekend_lunch = may[may['weekend'] == 1]['lunch_proportion'].mean()
# getting the average lunch proportion for non-weekend days
non_weekend_lunch = may[may['weekend'] == 0]['lunch_proportion'].mean()
# calculating the difference
weekend_lunch_effect = weekend_lunch - non_weekend_lunch

# getting the average snacks proportion for weekend days
weekend_snacks = may[may['weekend'] == 1]['snacks_proportion'].mean()
# getting the average snacks proportion for non-weekend days
non_weekend_snacks = may[may['weekend'] == 0]['snacks_proportion'].mean()
# calculating the difference
weekend_snacks_effect = weekend_snacks - non_weekend_snacks

# getting the average dinner proportion for weekend days
weekend_dinner = may[may['weekend'] == 1]['dinner_proportion'].mean()
# getting the average dinner proportion for non-weekend days
non_weekend_dinner = may[may['weekend'] == 0]['dinner_proportion'].mean()
# calculating the difference
weekend_dinner_effect = weekend_dinner - non_weekend_dinner

print((weekend_breakfast_effect + weekend_lunch_effect + weekend_snacks_effect + weekend_dinner_effect).mean())
# Out:
# 0.39331546620997637

# %%
# getting the effect of weekend on dinner
weekend_dinner = may[may['weekend'] == 1]['breakfast_proportion'].mean()
weekday_dinner = may[may['weekend'] == 0]['breakfast_proportion'].mean()

weekend_effect = weekend_dinner - weekday_dinner
weekend_effect
# Out:
# 0.1155355502207997

# %%
# saving the dataset
may.to_csv('../may.csv', index=False)

# %%
# applying all transformations to the june dataset
def update_month(month, breakfast_max, lunch_max, snacks_max, dinner_max, features):
    # adding the footfall columns
    month['breakfast_footfall'] = month.apply(lambda x: max_footfall(breakfast_max, x['day']), axis=1)
    month['lunch_footfall'] = month.apply(lambda x: max_footfall(lunch_max, x['day']), axis=1)
    month['snacks_footfall'] = month.apply(lambda x: max_footfall(snacks_max, x['day']), axis=1)
    month['dinner_footfall'] = month.apply(lambda x: max_footfall(dinner_max, x['day']), axis=1)

    # adding the proportion columns
    month['breakfast_proportion'] = month['breakfast']/month['breakfast_footfall']
    month['lunch_proportion'] = month['lunch']/month['lunch_footfall']
    month['snacks_proportion'] = month['snacks']/month['snacks_footfall']
    month['dinner_proportion'] = month['dinner']/month['dinner_footfall']

    # adding the feature columns
    for feature in features:
        month[feature] = 0

    # updating the feature columns
    bogo_days = ['Wednesday', 'Friday']
    month.loc[month['day'].isin(bogo_days), 'bogo'] = 1

    chicken_days = ['Monday', 'Wednesday', 'Friday']
    month.loc[month['day'].isin(chicken_days), 'chicken'] = 1

    weekend_days = ['Saturday', 'Sunday']
    month.loc[month['day'].isin(weekend_days), 'weekend'] = 1

    return month

# %%
june.dinner.max()
# Out:
# 311

# %%
june = update_month(june, 300, 370, 500, 350, features)
june.head(7)
# Out:
#          date  breakfast  lunch  snacks  dinner        day month  \
# 31 2023-06-01         69     88      65      71   Thursday  June
# 32 2023-06-02         81     80      82      37     Friday  June
# 33 2023-06-03         47     55      61      72   Saturday  June
# 34 2023-06-04         62     79      19      31     Sunday  June
# 35 2023-06-05         75    115      50      85     Monday  June
# 36 2023-06-06         72    102      53      87    Tuesday  June
# 37 2023-06-07         84    121      74      98  Wednesday  June
#
#     breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 31                 300             370              500  ...
# 32                 300             370              500  ...
# 33                 238             308              438  ...
# 34                 238             308              438  ...
# 35                 300             370              500  ...
# 36                 300             370              500  ...
# ...

# %%
# creating a 2 x 2 grid of plots
fig, axes = plt.subplots(2, 2, figsize=(20, 10))

# plotting the foot fall for breakfast against the date
sns.lineplot(ax=axes[0, 0], x="date", y="breakfast", data=june)
axes[0, 0].set_title('June Breakfast Footfall')
# rotating the x-axis labels
axes[0, 0].set_xticklabels(axes[0, 0].get_xticklabels(), rotation=45)

# plotting the foot fall for lunch against the date
sns.lineplot(ax=axes[0, 1], x="date", y="lunch", data=june)
axes[0, 1].set_title('June Lunch Footfall')
# rotating the x-axis labels
axes[0, 1].set_xticklabels(axes[0, 1].get_xticklabels(), rotation=45)

# plotting the foot fall for snacks against the date
sns.lineplot(ax=axes[1, 0], x="date", y="snacks", data=june)
axes[1, 0].set_title('June Snacks Footfall')
# rotating the x-axis labels
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45)

# plotting the foot fall for dinner against the date
sns.lineplot(ax=axes[1, 1], x="date", y="dinner", data=june)
axes[1, 1].set_title('June Dinner Footfall')
# rotating the x-axis labels
axes[1, 1].set_xticklabels(axes[1, 1].get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()

# %%
# Convert the date column to datetime objects
june['date'] = pd.to_datetime(june['date'], format='%d-%m-%Y %H:%M')

# Updating the footfall for June for the dates 1st to 9th of June
june.loc[(june['date'] >= '2023-06-01') & (june['date'] <= '2023-06-09'), 'breakfast_footfall'] = 100
june.loc[(june['date'] >= '2023-06-01') & (june['date'] <= '2023-06-09'), 'lunch_footfall'] = 150
june.loc[(june['date'] >= '2023-06-01') & (june['date'] <= '2023-06-09'), 'snacks_footfall'] = 100
june.loc[(june['date'] >= '2023-06-01') & (june['date'] <= '2023-06-09'), 'dinner_footfall'] = 120

# Updating the footfall for June for the dates 26th till 29th of June
june.loc[(june['date'] >= '2023-06-26') & (june['date'] <= '2023-06-29'), 'breakfast_footfall'] = 70
june.loc[(june['date'] >= '2023-06-26') & (june['date'] <= '2023-06-29'), 'lunch_footfall'] = 110
june.loc[(june['date'] >= '2023-06-26') & (june['date'] <= '2023-06-29'), 'snacks_footfall'] = 80
june.loc[(june['date'] >= '2023-06-26') & (june['date'] <= '2023-06-29'), 'dinner_footfall'] = 100

# %%
# recalculating the proportion columns
june['breakfast_proportion'] = june['breakfast']/june['breakfast_footfall']
june['lunch_proportion'] = june['lunch']/june['lunch_footfall']
june['snacks_proportion'] = june['snacks']/june['snacks_footfall']
june['dinner_proportion'] = june['dinner']/june['dinner_footfall']

june.head(15)
# Out:
#          date  breakfast  lunch  snacks  dinner        day month  \
# 31 2023-06-01         69     88      65      71   Thursday  June
# 32 2023-06-02         81     80      82      37     Friday  June
# 33 2023-06-03         47     55      61      72   Saturday  June
# 34 2023-06-04         62     79      19      31     Sunday  June
# 35 2023-06-05         75    115      50      85     Monday  June
# 36 2023-06-06         72    102      53      87    Tuesday  June
# 37 2023-06-07         84    121      74      98  Wednesday  June
# 38 2023-06-08         76     79      54      80   Thursday  June
# 39 2023-06-09         73    104      62      59     Friday  June
# 40 2023-06-10         42     73      39      87   Saturday  June
# 41 2023-06-11         39    121      60     217     Sunday  June
# 42 2023-06-12        247    330     486     283     Monday  June
# 43 2023-06-13        272    301     488     214    Tuesday  June
# ...

# %%
# doing some visualizations
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x="day", y="breakfast_proportion", data=june)
ax.set_title('June Breakfast Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="lunch_proportion", data=june)
ax.set_title('June Lunch Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="snacks_proportion", data=june)
ax.set_title('June Snacks Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="dinner_proportion", data=june)
ax.set_title('June Dinner Proportion')
plt.show()

# %%
# concatenating the may and june datasets
may_june = pd.concat([may, june], ignore_index=True)
may_june.head()
# Out:
#                date  breakfast  lunch  snacks  dinner        day month  \
# 0  01-05-2023 00:00        111    195     108     137     Monday   May
# 1  02-05-2023 00:00         95    175     115     138    Tuesday   May
# 2  03-05-2023 00:00         95    203     129     134  Wednesday   May
# 3  04-05-2023 00:00         93    184     131     179   Thursday   May
# 4  05-05-2023 00:00        112    121      95     117     Friday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 0                 215             277              215  ...
# 1                 215             277              215  ...
# 2                 215             277              215  ...
# 3                 215             277              215  ...
# 4                 215             277              215  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 0           0.637209     0            0        1        0     0      0
# ...

# %%
# doing some visualizations
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x="day", y="breakfast_proportion", data=may_june)
ax.set_title('May_June Breakfast Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="lunch_proportion", data=may_june)
ax.set_title('May_June Lunch Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="snacks_proportion", data=may_june)
ax.set_title('May_June Snacks Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="dinner_proportion", data=may_june)
ax.set_title('May_June Dinner Proportion')
plt.show()

# %%
print(july.breakfast.max())
print(july.lunch.max())
print(july.dinner.max())
print(july.snacks.max())
# Out:
# 81
# 100
# 78
# 69

# %%
def update_holiday_month(month, breakfast_max, lunch_max, snacks_max, dinner_max, features):
    # adding the proportion columns
    month['breakfast_proportion'] = month['breakfast']/breakfast_max
    month['lunch_proportion'] = month['lunch']/lunch_max
    month['snacks_proportion'] = month['snacks']/snacks_max
    month['dinner_proportion'] = month['dinner']/dinner_max

    # adding the feature columns
    for feature in features:
        month[feature] = 0

    # updating the feature columns
    bogo_days = ['Wednesday', 'Friday']
    month.loc[month['day'].isin(bogo_days), 'bogo'] = 1

    chicken_days = ['Monday', 'Wednesday', 'Friday']
    month.loc[month['day'].isin(chicken_days), 'chicken'] = 1

    weekend_days = ['Saturday', 'Sunday']
    month.loc[month['day'].isin(weekend_days), 'weekend'] = 1

    return month

# %%
july = update_holiday_month(july, 89, 124, 89, 89, features)
july.head(7)
# Out:
#                 date  breakfast  lunch  snacks  dinner        day month  \
# 61  01-07-2023 00:00         41     66      31      55   Saturday  July
# 62  02-07-2023 00:00         43     60      45      50     Sunday  July
# 63  03-07-2023 00:00         59     91      31      44     Monday  July
# 64  04-07-2023 00:00         63     21      69      67    Tuesday  July
# 65  05-07-2023 00:00         81    100      60      73  Wednesday  July
# 66  06-07-2023 00:00         50     78      69      64   Thursday  July
# 67  07-07-2023 00:00         40     87      54      77     Friday  July
#
#     breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 61                  27              62               27  ...
# 62                  27              62               27  ...
# 63                  89             124               89  ...
# 64                  89             124               89  ...
# 65                  89             124               89  ...
# ...

# %%
# doing some visualizations
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x="day", y="breakfast_proportion", data=july)
ax.set_title('July Breakfast Proportion')
plt.show()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="lunch_proportion", data=july)
ax.set_title('July Lunch Proportion')

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="snacks_proportion", data=july)
ax.set_title('July Snacks Proportion')

plt.figure(figsize=(10, 6))
ax = sns.barplot(x="day", y="dinner_proportion", data=july)
ax.set_title('July Dinner Proportion')

plt.show()

# %%
may_june_july = pd.concat([may_june, july], ignore_index=True)

may_june_july['date'] = pd.to_datetime(may_june_july['date'], format='%d-%m-%Y %H:%M')

# %%
# doing trend analysis
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# from the 1st of May to the 30th of July
ax = sns.lineplot(x="date", y="breakfast_proportion", data=may_june_july)
ax.set_title('Breakfast Proportion')
plt.show()

# %%
# getting the rows with breakfast proportion greater than 1
may_june_july[may_june_july['dinner_proportion'] > 1]
# Out:
#         date  breakfast  lunch  snacks  dinner       day month  \
# 5 2023-05-06        107    119      99     156  Saturday   May
# 6 2023-05-07         85    126     100     166    Sunday   May
#
#    breakfast_footfall  lunch_footfall  snacks_footfall  ...  \
# 5                 153             215              153  ...
# 6                 153             215              153  ...
#
#    dinner_proportion  bogo  celebration  chicken  weekend  exam  guest  \
# 5           1.019608     0            0        0        1     0      0
# 6           1.084967     0            0        0        1     0      0
#
#    holiday  fasting  north
# 5        0        0      0
# 6        0        0      0
#
# [2 rows x 24 columns]
