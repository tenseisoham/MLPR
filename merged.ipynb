# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
# reading the file
df = pd.read_csv('horrid.csv')
df.head()
# Out:
#    Unnamed: 0        Date  B.FAST  LUNCH  Snacks   DINNER Assorted Flakes  \
# 0           0  05-05-2023     112    121      95      117      Cornflakes
# 1           1  07-05-2023      85    126     100      166          Chocos
# 2           2  09-05-2023      90    172     127      181      Cornflakes
# 3           3  13-05-2023      78    137     115       97      Cornflakes
# 4           4  14-05-2023      83    176     124      131          Chocos
#
#   Seasonal Fruits         Egg         Main 1                     Main 2  \
# 0           Apple  Chana Chat         uttpam   Coconut Chutney/ Sambhar
# 1          Papaya  boiled egg  Sooji Uttapam   Coconut Chutney/ Sambhar
# 2             NaN  Boiled Egg            NaN                        NaN
# 3           Apple  Chana Chat    Masala Dosa   Coconut Chutney/ Sambhar
# 4      Musk melon     Sprouts  Sooji Uttapam   Coconut Chutney/ Sambhar
#
#                 Accompaniment        Bread  Beverage1           Beverage2  \
# ...

# %%
# creating a dataframe with only numeric columns from the original dataframe
df1 = df.select_dtypes(include=['int64', 'float64'])
df1.head()
# Out:
#    Unnamed: 0  B.FAST  LUNCH  Snacks   DINNER  Unnamed: 36  Unnamed: 37  \
# 0           0     112    121      95      117          NaN          NaN
# 1           1      85    126     100      166          NaN          NaN
# 2           2      90    172     127      181          NaN          NaN
# 3           3      78    137     115       97          NaN          NaN
# 4           4      83    176     124      131          NaN          NaN
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 34
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
